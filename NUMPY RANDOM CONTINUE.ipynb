# %%
from numpy import random

x = random.chisquare(df=2, size=(2, 3))

print(x)
# Out:
# [[2.26944408 1.86754504 2.62409946]
#  [7.12933375 0.20622957 1.25370901]]

# %%
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.chisquare(df=1, size=1000), hist=True)

plt.show()

# %%
from numpy import random

x = random.rayleigh(scale=2, size=(2, 3))

print(x)
# Out:
# [[2.16979313 2.85277104 4.16414664]
#  [3.71648011 2.89461962 3.22024959]]

# %%
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(random.rayleigh(size=1000), hist=False)

plt.show()

# %%
from numpy import random

x = random.pareto(a=2, size=(2, 3))

print(x)
# Out:
# [[0.03372718 0.57576565 3.74955396]
#  [0.7384316  0.02239955 0.25892681]]

# %%
sns.distplot(random.pareto(a=2, size=1000), kde=True,hist = True)

plt.show()

# %%
from numpy import random

x = random.zipf(a=2, size=(2, 3))

print(x)
# Out:
# [[14  2  1]
#  [ 2 30  1]]

# %%
x = random.zipf(a=2, size=1000)
sns.distplot(x[x<10], kde=False)

plt.show()
